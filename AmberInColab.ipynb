# %%
#This notebook will help you get AmberTools working in Colab
#Collaboratively developed by 
#Nikita Mishra. CSU Los Angeles. nmishra2@calstatela.edu
#Nikesh Mishra. Stanford University. nikesh01@stanford.edu

# %%
#Install latest Miniconda
# %%bash
MINICONDA_INSTALLER_SCRIPT=Miniconda3-latest-Linux-x86_64.sh
MINICONDA_PREFIX=/usr/local
wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
chmod +x $MINICONDA_INSTALLER_SCRIPT
./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py38h27cfd23_1003
#     - ca-certificates==2020.10.14=0
#     - certifi==2020.6.20=pyhd3eb1b0_3
#     - cffi==1.14.3=py38h261ae71_2
#     - chardet==3.0.4=py38h06a4308_1003
#     - conda-package-handling==1.7.2=py38h03888b9_0
#     - conda==4.9.2=py38h06a4308_0
#     - cryptography==3.2.1=py38h3c74f83_1
#     - idna==2.10=py_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20191231=h14c3975_1
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1h=h7b6447c_0
#     - pip==20.2.4=py38h06a4308_0
#     - pycosat==0.6.3=py38h7b6447c_1
#     - pycparser==2.20=py_2
#     - pyopenssl==19.1.0=pyhd3eb1b0_1
#     - pysocks==1.7.1=py38h06a4308_0
# ...

# %%
#Verify Conda is installed by
# !/usr/local/bin/conda --version
# Out:
# conda 4.9.2

# %%
#Check python version
# !python -V
# Out:
# Python 3.8.5

# %%
#If python_version does not equal required version of the Amber version you're using, then update it
#e.g. Amber20 requires Python 3.9
# !conda install python=3.9
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotlipy-0.7.0             |py39h27cfd23_1003         324 KB
#     ca-certificates-2021.1.19  |       h06a4308_0         121 KB
#     certifi-2020.12.5          |   py39h06a4308_0         140 KB
#     cffi-1.14.4                |   py39h261ae71_0         226 KB
#     chardet-3.0.4              |py39h06a4308_1003         174 KB
#     conda-4.9.2                |   py39h06a4308_0         2.9 MB
#     conda-package-handling-1.7.2|   py39h27cfd23_1         886 KB
#     cryptography-3.3.1         |   py39h3c74f83_0         561 KB
# ...

# %%
#Recheck Python version
# !python -V
# Out:
# Python 3.9.1

# %%
#Create new Python environement and install Amber20 by:
# %%bash
eval "$(conda shell.bash hook)" # copy conda command to shell
conda activate AmberTools20
conda env list
python --version
conda install -c conda-forge ambertools=20
# Out:
# # conda environments:
# #
# base                     /usr/local
# AmberTools20          *  /usr/local/envs/AmberTools20
#
# Python 3.9.1
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
#Setup AMBERHOME  - base directory for AmberTools
#Add AmberTools executables from $AMBERHOME/bin to PATH for ease of use 
import os
os.environ['AMBERHOME'] = "/usr/local/envs/AmberTools20"
os.environ['PATH'] += os.pathsep + "/usr/local/envs/AmberTools20/bin/"

# %%
#Verify AMBERHOME listing any known directory for AmberTools20
# !ls $AMBERHOME/dat/leap/cmd
# Out:
# leaprc.amberdyes	leaprc.music		     leaprc.RNA.LJbb
# leaprc.conste		leaprc.phosaa10		     leaprc.RNA.OL3
# leaprc.constph		leaprc.phosaa14SB	     leaprc.RNA.ROC
# leaprc.DNA.bsc1		leaprc.phosaa19SB	     leaprc.RNA.Shaw
# leaprc.DNA.OL15		leaprc.protein.fb15	     leaprc.RNA.YIL
# leaprc.ffAM1		leaprc.protein.ff03.r1	     leaprc.water.fb3
# leaprc.ffPM3		leaprc.protein.ff03ua	     leaprc.water.fb4
# leaprc.gaff		leaprc.protein.ff14SB	     leaprc.water.opc
# leaprc.gaff2		leaprc.protein.ff14SB_modAA  leaprc.water.spce
# leaprc.GLYCAM_06EPb	leaprc.protein.ff14SBonlysc  leaprc.water.spceb
# leaprc.GLYCAM_06j-1	leaprc.protein.ff15ipq	     leaprc.water.tip3p
# leaprc.lipid14		leaprc.protein.ff15ipq-vac   leaprc.water.tip4pd
# leaprc.lipid17		leaprc.protein.ff19ipq	     leaprc.water.tip4pew
# leaprc.mimetic.ff15ipq	leaprc.protein.ff19SB	     leaprc.xFPchromophores
# leaprc.modrna08		leaprc.protein.ff19SB_modAA  oldff

# %%
#Start using AmberTools!
#Note that there is an interesting issue with this mounting which we are yet to solve. Upon emplying tleap, your input will initially appear as hidden 
#characters, like a password; however, after you hit 'enter' and run the command, you will be able to see the command you have inputted.
# !tleap -s -f $AMBERHOME/dat/leap/cmd/leaprc.ffAM1
# Out:
# -I: Adding /usr/local/dat/leap/prep to search path.
# -I: Adding /usr/local/dat/leap/lib to search path.
# -I: Adding /usr/local/dat/leap/parm to search path.
# -I: Adding /usr/local/dat/leap/cmd to search path.
# -s: Ignoring startup file: leaprc
# -f: Source /usr/local/envs/AmberTools20/dat/leap/cmd/leaprc.ffAM1.
#
# Welcome to LEaP!
# Sourcing: /usr/local/envs/AmberTools20/dat/leap/cmd/leaprc.ffAM1
# Log file: ./leap.log
# Loading parameters: /usr/local/dat/leap/parm/parmAM1.dat
# Reading title:
# PARMAM1 for proteins to reproduce semiempirical geometries
# Loading library: /usr/local/dat/leap/lib/all_nucleic94.lib
# Loading library: /usr/local/dat/leap/lib/all_aminoAM1.lib
# Loading library: /usr/local/dat/leap/lib/all_aminoct94.lib
# Loading library: /usr/local/dat/leap/lib/all_aminont94.lib
# Loading library: /usr/local/dat/leap/lib/ions94.lib
# Loading library: /usr/local/dat/leap/lib/solvents.lib
# > set default PBRadii mbondi2
# Using H(N)-modified Bondi radii
# >
